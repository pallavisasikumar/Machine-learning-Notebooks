# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
data=pd.read_csv('CarPrice_Assignment.csv')
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 data.columns()
#
# TypeError: 'Index' object is not callable

# %%
data=data.drop(['car_ID','symboling','enginelocation','doornumber','fueltype'],axis=1)
data
# Out:
#                       CarName aspiration      carbody drivewheel  wheelbase  \
# 0          alfa-romero giulia        std  convertible        rwd       88.6
# 1         alfa-romero stelvio        std  convertible        rwd       88.6
# 2    alfa-romero Quadrifoglio        std    hatchback        rwd       94.5
# 3                 audi 100 ls        std        sedan        fwd       99.8
# 4                  audi 100ls        std        sedan        4wd       99.4
# ..                        ...        ...          ...        ...        ...
# 200           volvo 145e (sw)        std        sedan        rwd      109.1
# 201               volvo 144ea      turbo        sedan        rwd      109.1
# 202               volvo 244dl        std        sedan        rwd      109.1
# 203                 volvo 246      turbo        sedan        rwd      109.1
# 204               volvo 264gl      turbo        sedan        rwd      109.1
#
# ...

# %%
x=data.drop('price',axis=1)
y=data['price']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le1=LabelEncoder()
le2=LabelEncoder()
le3=LabelEncoder()
le4=LabelEncoder()
le5=LabelEncoder()
le6=LabelEncoder()

# %%
x['CarName']=le1.fit_transform(x['CarName'])
x['fueltype']=le2.fit_transform(x['fueltype'])
x['aspiration']=le3.fit_transform(x['aspiration'])
x['doornumber']=le4.fit_transform(x['doornumber'])
x['carbody']=le5.fit_transform(x['carbody'])
x['drivewheel']=le6.fit_transform(x['drivewheel'])
x
# Out:
#      CarName  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          2         1           0           1        0           2
# 1          3         1           0           1        0           2
# 2          1         1           0           1        2           2
# 3          4         1           0           0        3           1
# 4          5         1           0           0        3           0
# ..       ...       ...         ...         ...      ...         ...
# 200      139         1           0           0        3           2
# 201      138         1           1           0        3           2
# 202      140         1           0           0        3           2
# 203      142         0           1           0        3           2
# 204      143         1           1           0        3           2
#
#      wheelbase  carlength  carwidth  carheight  ...  cylindernumber  \
# 0         88.6      168.8      64.1       48.8  ...            four
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.25,random_state=30)

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 x_train=scaler.fit_transform(x_train)
#       2 x_test=scaler.transform(x_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:416, in MinMaxScaler.fit(self, X, y)
#     414 # Reset internal state before fitting
# ...
